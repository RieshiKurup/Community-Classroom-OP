# %% [markdown]
# <a href="https://colab.research.google.com/github/RieshiKurup/Community-Classroom-OP/blob/main/BasicML_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 421ms/step - loss: 34.7235
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 27.3250
# Epoch 3/500
# 1/1 [==============================] - 0s 12ms/step - loss: 21.5042
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 16.9245
# Epoch 5/500
# 1/1 [==============================] - 0s 12ms/step - loss: 13.3213
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 10.4863
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2558
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 6.5008
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1200
# Epoch 10/500
# 1/1 [==============================] - 0s 13ms/step - loss: 4.0335
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1786
# Epoch 12/500
# ...

# %%
print(model.predict([1.0]))
# Out:
# 1/1 [==============================] - 0s 36ms/step
# [[3.9990954]]
